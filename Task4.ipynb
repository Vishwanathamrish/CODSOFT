# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv("/workspaces/CODSOFT/advertising.csv")

# %%
print(df.head())
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
print(df.shape)
# Out:
# (200, 4)

# %%
print(df.describe())
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
sns.pairplot(df, x_vars=['TV', 'Radio', 'Newspaper'], y_vars='Sales', kind='scatter')
plt.show()

# %%
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df[['TV']], df[['Sales']], test_size=0.3, random_state=0)

# %%
model = RandomForestRegressor(n_estimators=100, random_state=0)
model.fit(X_train, Y_train.values.ravel())
# Out:
# RandomForestRegressor(random_state=0)

# %%
res = model.predict(X_test)
print(res)
# Out:
# [10.964      11.196      11.715      19.11       16.74       11.707
#   5.957      21.274       9.145      17.063      19.203      12.987
#  15.67       19.815      10.485      13.357      19.037       4.225
#  12.252      20.99       20.473      11.3        16.84135714 14.473
#  11.575      12.161      18.177      18.13566667 16.89066667  9.139
#  10.526      17.67813333 21.821      24.189       6.41793333  7.12175
#  11.681      19.90771667 10.828       9.139      10.289       7.46
#  13.736      19.884      18.991      11.266       5.957       8.8276
#  11.598      12.031      16.044      21.638      20.305      20.676
#  10.298      11.815      20.454      16.40585714 17.654       6.143     ]

# %%
plt.plot(res)

# %%
plt.scatter(X_test, Y_test)
plt.xlabel('TV')
plt.ylabel('Sales')
plt.show()

# %%
plt.plot(X_test, res, 'r')
plt.xlabel('TV')
plt.ylabel('Sales')
plt.show()
